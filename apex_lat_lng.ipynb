# %%
import pandas as pd
import numpy as np

attached_file = "attached_apex.csv"
detached_file = "detached_apex.csv"

attached_df = pd.read_csv(attached_file)
detached_df = pd.read_csv(detached_file)


# Dependencies for geocoding
import requests
import json
import gmaps
from pprint import pprint

#Import API key
from api_keys import g_key

# %%
detached_df.head()
#attached_df.head()
# Out:
#      MLS #  Status                Address  City    Zip Closing Date  \
# 0  2307699  CLOSED     472 NC 751 Highway  Apex  27523    9/28/2020
# 1  2198042  CLOSED      5520 Bobbitt Road  Apex  27539    8/29/2018
# 2  2177583  CLOSED      5524 Bobbitt Road  Apex  27539     5/9/2018
# 3  2194561  CLOSED  106 N Bellhaven Drive  Apex  27539     7/6/2018
# 4  2197718  CLOSED       8325 Rhodes Road  Apex  27603    9/27/2018
#
#             Subdivision LvngAreaSF  YrBlt  Beds  FBths  HBths Property Type  \
# 0  Not in a Subdivision      1,480   1989     2      2      0      Detached
# 1  Not in a Subdivision        640   1962     2      0      0      Detached
# 2  Not in a Subdivision      1,083   1953     2      1      0      Detached
# 3  Not in a Subdivision      1,344   1997     3      2      0      Detached
# 4      Washington Homes        480   1960     2      1      0      Detached
#
#     List Price   Sold Price  Days On Market HOA Y/N  Garage          Acres  \
# ...

# %% [markdown]
# ## DETACHED

# %% [markdown]
# ## Use geocoding via googlemaps API to pull lat/long

# %%
#add NC to dataframe
detached_df['State'] = "NC"
detached_df
# Out:
#         MLS #  Status                 Address  City    Zip Closing Date  \
# 0     2307699  CLOSED      472 NC 751 Highway  Apex  27523    9/28/2020
# 1     2198042  CLOSED       5520 Bobbitt Road  Apex  27539    8/29/2018
# 2     2177583  CLOSED       5524 Bobbitt Road  Apex  27539     5/9/2018
# 3     2194561  CLOSED   106 N Bellhaven Drive  Apex  27539     7/6/2018
# 4     2197718  CLOSED        8325 Rhodes Road  Apex  27603    9/27/2018
# ...       ...     ...                     ...   ...    ...          ...
# 5109  2284447  CLOSED  809 Journeys Rest Lane  Apex  27523    9/10/2020
# 5110  2344559  CLOSED     478 Democracy Place  Apex  27502   12/16/2019
# 5111  2303170  CLOSED     117 Lexington Drive  Apex  27523    2/20/2020
# 5112  2303517  CLOSED     261 Lexington Drive  Apex  27523    2/22/2020
# 5113  2256968  CLOSED           189 Shad Lane  Apex  27523   11/19/2019
#
#                Subdivision LvngAreaSF  YrBlt  Beds  ...     List Price  \
# ...

# %%
address = detached_df['Address']
city = detached_df['City']
zipcode = detached_df['Zip']
state = detached_df['State']

full_address = address + "," + city + "," + state + "," + zipcode
full_address_list = list(full_address)
full_address_list
# Out:
# ['472 NC 751 Highway,Apex,NC,27523',
#  '5520 Bobbitt Road,Apex,NC,27539',
#  '5524 Bobbitt Road,Apex,NC,27539',
#  '106 N Bellhaven Drive,Apex,NC,27539',
#  '8325 Rhodes Road,Apex,NC,27603',
#  '304 S Hughes Street,Apex,NC,27502',
#  '2700 Optimist Farm Road,Apex,NC,27539-8605',
#  '410 Second Street,Apex,NC,27502',
#  '201 West Street,Apex,NC,27502',
#  '5112 Sunset Lake Road,Apex,NC,27539',
#  '5807 Old Smithfield Road,Apex,NC,27539',
#  '5525 Bobbitt Road,Apex,NC,27539-7288',
#  '8724 Stephenson Road,Apex,NC,27539',
#  '204 West Street,Apex,NC,27502',
#  '419 Second Street,Apex,NC,27502-2045',
#  '113 West Street,Apex,NC,27502-2054',
#  '419 Ashley Road,Apex,NC,27539',
#  '2760 Brantley Drive,Apex,NC,27539',
#  '2737 Brantley Drive,Apex,NC,27539-9707',
#  '8000 Baybark Circle,Apex,NC,27539',
#  '3033 Evans Road,Apex,NC,27502',
#  '625 Tingen Road,Apex,NC,27502',
#  '1521 Salem Church Road,Apex,NC,27523',
#  '2624 Brad Court,Apex,NC,27539-9739',
# ...

# %%
#add full address to column to df
detached_df['Full_Address'] = full_address
detached_df.drop(columns='Full Address')
# Out:
#         MLS #  Status                 Address  City    Zip Closing Date  \
# 0     2307699  CLOSED      472 NC 751 Highway  Apex  27523    9/28/2020
# 1     2198042  CLOSED       5520 Bobbitt Road  Apex  27539    8/29/2018
# 2     2177583  CLOSED       5524 Bobbitt Road  Apex  27539     5/9/2018
# 3     2194561  CLOSED   106 N Bellhaven Drive  Apex  27539     7/6/2018
# 4     2197718  CLOSED        8325 Rhodes Road  Apex  27603    9/27/2018
# ...       ...     ...                     ...   ...    ...          ...
# 5109  2284447  CLOSED  809 Journeys Rest Lane  Apex  27523    9/10/2020
# 5110  2344559  CLOSED     478 Democracy Place  Apex  27502   12/16/2019
# 5111  2303170  CLOSED     117 Lexington Drive  Apex  27523    2/20/2020
# 5112  2303517  CLOSED     261 Lexington Drive  Apex  27523    2/22/2020
# 5113  2256968  CLOSED           189 Shad Lane  Apex  27523   11/19/2019
#
#                Subdivision LvngAreaSF  YrBlt  Beds  ...     Sold Price  \
# ...

# %%
# Target address
geo_address = full_address_list

address_latlng = []


for address in geo_address:
    
        try:
            
            target_url = ('https://maps.googleapis.com/maps/api/geocode/json?'
                          'address={0}&key={1}').format(address, "gkey")
        
            geo_data = requests.get(target_url).json()["results"][0]
            
            data = {
                "address": address,
                "lat": geo_data["geometry"]["location"]["lat"],
                "lng": geo_data["geometry"]["location"]["lng"]
            }
        
        
            address_latlng.append(data)
            
            #lat.append(geo_data["geometry"]["location"]["lat"])
            #lng.append(geo_data["geometry"]["location"]["lng"])
        
        except(KeyError, IndexError):
        
        
            data = {
                "address": address,
                "lat": "lat not found",
                "lng": "lng not found"
            }
        
        
            address_latlng.append(data)
            
            print(f"Couldnt find {address}")
            
            #add addresses not found to a list
            #not_found.append(address)
        
    

# Build the endpoint URL
# Out:
# Couldnt find 3004 Kildaire Dairy Way,Apex,NC,27539
# Couldnt find 3057 Kildaire Dairy Way,Apex,NC,27539
# Couldnt find 3049 Kildaire Dairy Way,Apex,NC,27539
# Couldnt find 3024 Kildaire Dairy Way,Apex,NC,27539
# Couldnt find 3045 Kildaire Dairy Way,Apex,NC,27539
# Couldnt find 3036 Kildaire Dairy Way,Apex,NC,27539
# Couldnt find 3032 Kildaire Dairy Way,Apex,NC,27539
# Couldnt find 3020 Kildaire Dairy Way,Apex,NC,27539
# Couldnt find 3041 Kildaire Dairy Way,Apex,NC,27539
# Couldnt find 3060 Kildaire Dairy Way,Apex,NC,27539
# Couldnt find 3056 Kildaire Dairy Way,Apex,NC,27539
# Couldnt find 3025 Kildaire Dairy Way,Apex,NC,27539
# Couldnt find 3037 Kildaire Dairy Way,Apex,NC,27539
# Couldnt find 3052 Kildaire Dairy Way,Apex,NC,27539
# Couldnt find 3029 Kildaire Dairy Way,Apex,NC,27539
# Couldnt find 3053 Kildaire Dairy Way,Apex,NC,27539

# %%
address_latlng
# Out:
# [{'address': '472 NC 751 Highway,Apex,NC,27523',
#   'lat': 35.7476388,
#   'lng': -78.9527545},
#  {'address': '5520 Bobbitt Road,Apex,NC,27539',
#   'lat': 35.6961165,
#   'lng': -78.83254629999999},
#  {'address': '5524 Bobbitt Road,Apex,NC,27539',
#   'lat': 35.696222,
#   'lng': -78.8331104},
#  {'address': '106 N Bellhaven Drive,Apex,NC,27539',
#   'lat': 35.668266,
#   'lng': -78.791703},
#  {'address': '8325 Rhodes Road,Apex,NC,27603',
#   'lat': 35.6643147,
#   'lng': -78.739318},
#  {'address': '304 S Hughes Street,Apex,NC,27502',
#   'lat': 35.7273667,
#   'lng': -78.8510818},
#  {'address': '2700 Optimist Farm Road,Apex,NC,27539-8605',
#   'lat': 35.6593892,
#   'lng': -78.7276596},
#  {'address': '410 Second Street,Apex,NC,27502',
#   'lat': 35.7274874,
#   'lng': -78.8569979},
#  {'address': '201 West Street,Apex,NC,27502',
#   'lat': 35.7257518,
#   'lng': -78.85690939999999},
#  {'address': '5112 Sunset Lake Road,Apex,NC,27539',
#   'lat': 35.6699371,
# ...

# %%
 # Run a request to endpoint and convert result to json
geo_data = requests.get(target_url).json()

# Print the json
pprint(geo_data)
# Out:
# {'results': [{'address_components': [{'long_name': '472',
#                                       'short_name': '472',
#                                       'types': ['street_number']},
#                                      {'long_name': 'North Carolina 751',
#                                       'short_name': 'NC-751',
#                                       'types': ['route']},
#                                      {'long_name': 'Apex',
#                                       'short_name': 'Apex',
#                                       'types': ['locality', 'political']},
#                                      {'long_name': 'New Hope',
#                                       'short_name': 'New Hope',
#                                       'types': ['administrative_area_level_3',
#                                                 'political']},
#                                      {'long_name': 'Chatham County',
# ...

# %%
detached_df['Lat'] = ""
detached_df['Lng'] = ""
detached_df
# Out:
#         MLS #  Status                 Address  City    Zip Closing Date  \
# 0     2307699  CLOSED      472 NC 751 Highway  Apex  27523    9/28/2020
# 1     2198042  CLOSED       5520 Bobbitt Road  Apex  27539    8/29/2018
# 2     2177583  CLOSED       5524 Bobbitt Road  Apex  27539     5/9/2018
# 3     2194561  CLOSED   106 N Bellhaven Drive  Apex  27539     7/6/2018
# 4     2197718  CLOSED        8325 Rhodes Road  Apex  27603    9/27/2018
# ...       ...     ...                     ...   ...    ...          ...
# 5109  2284447  CLOSED  809 Journeys Rest Lane  Apex  27523    9/10/2020
# 5110  2344559  CLOSED     478 Democracy Place  Apex  27502   12/16/2019
# 5111  2303170  CLOSED     117 Lexington Drive  Apex  27523    2/20/2020
# 5112  2303517  CLOSED     261 Lexington Drive  Apex  27523    2/22/2020
# 5113  2256968  CLOSED           189 Shad Lane  Apex  27523   11/19/2019
#
#                Subdivision LvngAreaSF  YrBlt  Beds  ...  Days On Market  \
# ...

# %%
not_found = [
"3004 Kildaire Dairy Way,Apex,NC,27539",
"3057 Kildaire Dairy Way,Apex,NC,27539",
"3049 Kildaire Dairy Way,Apex,NC,27539",
"3024 Kildaire Dairy Way,Apex,NC,27539",
"3045 Kildaire Dairy Way,Apex,NC,27539",
"3036 Kildaire Dairy Way,Apex,NC,27539",
"3032 Kildaire Dairy Way,Apex,NC,27539",
"3020 Kildaire Dairy Way,Apex,NC,27539",
"3041 Kildaire Dairy Way,Apex,NC,27539",
"3060 Kildaire Dairy Way,Apex,NC,27539",
"3056 Kildaire Dairy Way,Apex,NC,27539",
"3025 Kildaire Dairy Way,Apex,NC,27539",
"3037 Kildaire Dairy Way,Apex,NC,27539",
"3052 Kildaire Dairy Way,Apex,NC,27539",
"3029 Kildaire Dairy Way,Apex,NC,27539",
"3053 Kildaire Dairy Way,Apex,NC,27539"
]

not_found
# Out:
# ['3004 Kildaire Dairy Way,Apex,NC,27539',
#  '3057 Kildaire Dairy Way,Apex,NC,27539',
#  '3049 Kildaire Dairy Way,Apex,NC,27539',
#  '3024 Kildaire Dairy Way,Apex,NC,27539',
#  '3045 Kildaire Dairy Way,Apex,NC,27539',
#  '3036 Kildaire Dairy Way,Apex,NC,27539',
#  '3032 Kildaire Dairy Way,Apex,NC,27539',
#  '3020 Kildaire Dairy Way,Apex,NC,27539',
#  '3041 Kildaire Dairy Way,Apex,NC,27539',
#  '3060 Kildaire Dairy Way,Apex,NC,27539',
#  '3056 Kildaire Dairy Way,Apex,NC,27539',
#  '3025 Kildaire Dairy Way,Apex,NC,27539',
#  '3037 Kildaire Dairy Way,Apex,NC,27539',
#  '3052 Kildaire Dairy Way,Apex,NC,27539',
#  '3029 Kildaire Dairy Way,Apex,NC,27539',
#  '3053 Kildaire Dairy Way,Apex,NC,27539']

# %%
print(type(to_drop))

#insert "NA" to lat/lng values that were not found
for x in not_found:
    detached_df.at[detached_df.loc[detached_df["Full_Address"] == x].index.values[0], ["Lat", "Lng"]] = ["NA", "NA"]

detached_df.loc[detached_df["Full_Address"].isin(not_found)]
# Out:
# <class 'list'>
#         MLS #  Status                  Address  City    Zip Closing Date  \
# 2884  2328393  CLOSED  3004 Kildaire Dairy Way  Apex  27539    6/30/2020
# 3148  2327811  CLOSED  3057 Kildaire Dairy Way  Apex  27539    6/26/2020
# 3244  2325047  CLOSED  3049 Kildaire Dairy Way  Apex  27539    6/12/2020
# 3388  2309756  CLOSED  3024 Kildaire Dairy Way  Apex  27539    4/28/2020
# 3603  2334846  CLOSED  3045 Kildaire Dairy Way  Apex  27539    7/31/2020
# 3654  2342075  CLOSED  3036 Kildaire Dairy Way  Apex  27539    8/26/2020
# 3671  2340615  CLOSED  3032 Kildaire Dairy Way  Apex  27539    8/29/2020
# 3838  2321559  CLOSED  3020 Kildaire Dairy Way  Apex  27539    5/27/2020
# 3842  2313410  CLOSED  3041 Kildaire Dairy Way  Apex  27539    6/30/2020
# 3893  2338909  CLOSED  3060 Kildaire Dairy Way  Apex  27539    8/21/2020
# 4125  2346224  CLOSED  3056 Kildaire Dairy Way  Apex  27539    9/30/2020
# 4212  2345808  CLOSED  3025 Kildaire Dairy Way  Apex  27539    9/29/2020
# ...

# %%
#drop first full address for cleanup
detached_df.drop(columns='Full Address')
detached_df
# Out:
#         MLS #  Status                 Address  City    Zip Closing Date  \
# 0     2307699  CLOSED      472 NC 751 Highway  Apex  27523    9/28/2020
# 1     2198042  CLOSED       5520 Bobbitt Road  Apex  27539    8/29/2018
# 2     2177583  CLOSED       5524 Bobbitt Road  Apex  27539     5/9/2018
# 3     2194561  CLOSED   106 N Bellhaven Drive  Apex  27539     7/6/2018
# 4     2197718  CLOSED        8325 Rhodes Road  Apex  27603    9/27/2018
# ...       ...     ...                     ...   ...    ...          ...
# 5109  2284447  CLOSED  809 Journeys Rest Lane  Apex  27523    9/10/2020
# 5110  2344559  CLOSED     478 Democracy Place  Apex  27502   12/16/2019
# 5111  2303170  CLOSED     117 Lexington Drive  Apex  27523    2/20/2020
# 5112  2303517  CLOSED     261 Lexington Drive  Apex  27523    2/22/2020
# 5113  2256968  CLOSED           189 Shad Lane  Apex  27523   11/19/2019
#
#                Subdivision LvngAreaSF  YrBlt  Beds  ...  Days On Market  \
# ...

# %%
address_latlng
# Out:
# [{'address': '472 NC 751 Highway,Apex,NC,27523',
#   'lat': 35.7476388,
#   'lng': -78.9527545},
#  {'address': '5520 Bobbitt Road,Apex,NC,27539',
#   'lat': 35.6961165,
#   'lng': -78.83254629999999},
#  {'address': '5524 Bobbitt Road,Apex,NC,27539',
#   'lat': 35.696222,
#   'lng': -78.8331104},
#  {'address': '106 N Bellhaven Drive,Apex,NC,27539',
#   'lat': 35.668266,
#   'lng': -78.791703},
#  {'address': '8325 Rhodes Road,Apex,NC,27603',
#   'lat': 35.6643147,
#   'lng': -78.739318},
#  {'address': '304 S Hughes Street,Apex,NC,27502',
#   'lat': 35.7273667,
#   'lng': -78.8510818},
#  {'address': '2700 Optimist Farm Road,Apex,NC,27539-8605',
#   'lat': 35.6593892,
#   'lng': -78.7276596},
#  {'address': '410 Second Street,Apex,NC,27502',
#   'lat': 35.7274874,
#   'lng': -78.8569979},
#  {'address': '201 West Street,Apex,NC,27502',
#   'lat': 35.7257518,
#   'lng': -78.85690939999999},
#  {'address': '5112 Sunset Lake Road,Apex,NC,27539',
#   'lat': 35.6699371,
# ...

# %%
#detached_df['Lat'] = address_latlng[0]['lat']
detached_df
# Out:
#         MLS #  Status                 Address  City    Zip Closing Date  \
# 0     2307699  CLOSED      472 NC 751 Highway  Apex  27523    9/28/2020
# 1     2198042  CLOSED       5520 Bobbitt Road  Apex  27539    8/29/2018
# 2     2177583  CLOSED       5524 Bobbitt Road  Apex  27539     5/9/2018
# 3     2194561  CLOSED   106 N Bellhaven Drive  Apex  27539     7/6/2018
# 4     2197718  CLOSED        8325 Rhodes Road  Apex  27603    9/27/2018
# ...       ...     ...                     ...   ...    ...          ...
# 5109  2284447  CLOSED  809 Journeys Rest Lane  Apex  27523    9/10/2020
# 5110  2344559  CLOSED     478 Democracy Place  Apex  27502   12/16/2019
# 5111  2303170  CLOSED     117 Lexington Drive  Apex  27523    2/20/2020
# 5112  2303517  CLOSED     261 Lexington Drive  Apex  27523    2/22/2020
# 5113  2256968  CLOSED           189 Shad Lane  Apex  27523   11/19/2019
#
#                Subdivision LvngAreaSF  YrBlt  Beds  ...  Days On Market  \
# ...

# %% [markdown]
# ## TOWN HOMES

# %%
#add NC to dataframe
attached_df['State'] = "NC"
attached_df
# Out:
#         MLS #  Status                   Address  City    Zip Closing Date  \
# 0     2192440  CLOSED    202 Harbor Haven Drive  Apex  27502    6/28/2018
# 1     2173092  CLOSED         119 Halsmer Court  Apex  27502    3/15/2018
# 2     2264913  CLOSED      323 Port Haven Drive  Apex  27502     9/3/2019
# 3     2169851  CLOSED      315 Port Haven Drive  Apex  27502     4/6/2018
# 4     2280642  CLOSED      306 Port Haven Drive  Apex  27502   10/31/2019
# ...       ...     ...                       ...   ...    ...          ...
# 1533  2182370  CLOSED         583 Rowanwood Way  Apex  27502   10/31/2018
# 1534  2217545  CLOSED         560 Rowanwood Way  Apex  27502   11/30/2018
# 1535  2220987  CLOSED  2512 Rambling Creek Road  Apex  27523    1/31/2019
# 1536  2217544  CLOSED         566 Rowanwood Way  Apex  27502   11/21/2018
# 1537  2241241  CLOSED  2562 Rambling Creek Road  Apex  27523    4/25/2019
#
#                           Subdivision LvngAreaSF  YrBlt  Beds  ...  HBths  \
# ...

# %%
address2 = attached_df['Address']
city2 = attached_df['City']
zipcode2 = attached_df['Zip']
state2 = attached_df['State']

full_address2 = address2 + "," + city2 + "," + state2 + "," + zipcode2
full_address_list2 = list(full_address2)
full_address_list2
# Out:
# ['202 Harbor Haven Drive,Apex,NC,27502',
#  '119 Halsmer Court,Apex,NC,27502',
#  '323 Port Haven Drive,Apex,NC,27502',
#  '315 Port Haven Drive,Apex,NC,27502',
#  '306 Port Haven Drive,Apex,NC,27502',
#  '327 Port Haven Drive,Apex,NC,27502-4707',
#  '146 Anterbury Drive,Apex,NC,27502',
#  '109 Harbor Haven Drive,Apex,NC,27502',
#  '117 Shelter Haven Drive,Apex,NC,27502',
#  '121 Shelter Haven Drive,Apex,NC,27539',
#  '136 Old Grove Lane,Apex,NC,27502',
#  '137 Licorice Drive,Apex,NC,27502',
#  '109 Harbor Haven Drive,Apex,NC,27502',
#  '131 Anterbury Drive,Apex,NC,27502',
#  '105 Harbor Haven Drive,Apex,NC,27502',
#  '116 Eldon Lane,Apex,NC,27502',
#  '114 Eldon Lane,Apex,NC,27502',
#  '108 Harbor Haven Drive,Apex,NC,27502',
#  '113 Shelter Haven Drive,Apex,NC,27502-4789',
#  '106 Eldon Lane,Apex,NC,27502',
#  '715 Center Street,Apex,NC,27502',
#  '104 Shelter Haven Drive,Apex,NC,27502',
#  '134 Forthview Way,Apex,NC,27502',
#  '321 Port Haven Drive,Apex,NC,27502',
# ...

# %%
# Target address
geo_address2 = full_address_list2

address_latlng2 = []
not_found2 = []


for address in geo_address2:
    
        try:
            
            target_url = ('https://maps.googleapis.com/maps/api/geocode/json?'
                          'address={0}&key={1}').format(address, "AIzaSyCMS0VJQNS_xazPwErRkzG4pCxdq0_9P8I")
        
            geo_data = requests.get(target_url).json()["results"][0]
            
            data = {
                "address": address2,
                "lat": geo_data["geometry"]["location"]["lat"],
                "lng": geo_data["geometry"]["location"]["lng"]
            }
        
        
            address_latlng.append(data)
            
            #lat.append(geo_data["geometry"]["location"]["lat"])
            #lng.append(geo_data["geometry"]["location"]["lng"])
        
        except(KeyError, IndexError):
        
        
            data = {
                "address": address2,
                "lat": "lat not found",
                "lng": "lng not found"
            }
        
        
            address_latlng.append(data)
            
            print(f"Couldnt find {address2}")
            
            #add addresses not found to a list
            not_found2.append(address)
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     156             conn = connection.create_connection(
# --> 157                 (self._dns_host, self.port), self.timeout, **extra_kw
#     158             )
#
# ~\anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      83     if err is not None:
# ---> 84         raise err
#      85
#
# ~\anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      73                 sock.bind(source_address)
# ---> 74             sock.connect(sa)
#      75             return sock
#
# ...
